# %% [markdown]
# <a href="https://colab.research.google.com/github/xcl-esc/Analise_Airbnb/blob/main/Limpeza_e_manipulacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Essa primeira vista serve pra limpar os dados e testar alguns comandos de visualização dos dados.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/analise_de_dados/Testes/
# Out:
# /content/drive/MyDrive/analise_de_dados/Testes

# %%
import pandas as pd

# %%
df = pd.read_csv('dados.csv')
df.shape
# Out:
# (21286, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21286 entries, 0 to 21285
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           21286 non-null  int64
#  1   listing_url                  21286 non-null  object
#  2   scrape_id                    21286 non-null  int64
#  3   last_scraped                 21286 non-null  object
#  4   source                       21286 non-null  object
#  5   name                         21286 non-null  object
#  6   description                  20766 non-null  object
#  7   host_id                      21286 non-null  int64
#  8   host_name                    20534 non-null  object
#  9   host_since                   20495 non-null  object
#  10  neighbourhood                8320 non-null   object
#  11  neighbourhood_cleansed       21286 non-null  object
#  12  latitude                     21286 non-null  object
#  13  longitude                    21286 non-null  object
#  14  room_type                    21286 non-null  object
#  15  accommodates                 21286 non-null  int64
#  16  bathrooms                    19465 non-null  float64
#  17  bedrooms                     20919 non-null  float64
#  18  beds                         19480 non-null  float64
#  19  price                        19486 non-null  object
#  20  review_scores_rating         16919 non-null  float64
#  21  review_scores_accuracy       16914 non-null  float64
#  22  review_scores_cleanliness    16915 non-null  float64
#  23  review_scores_checkin        16915 non-null  float64
#  24  review_scores_communication  16914 non-null  float64
#  25  review_scores_location       16914 non-null  float64
#  26  review_scores_value          16914 non-null  float64
# dtypes: float64(10), int64(4), object(13)
# memory usage: 4.4+ MB

# %%
df.head()
# Out:
#                     id                                       listing_url  \
# 0   752318531145700331   https://www.airbnb.com/rooms/752318531145700331
# 1  1411843238290322081  https://www.airbnb.com/rooms/1411843238290322081
# 2  1339188406746847719  https://www.airbnb.com/rooms/1339188406746847719
# 3  1050604592912820183  https://www.airbnb.com/rooms/1050604592912820183
# 4  1349515326730602111  https://www.airbnb.com/rooms/1349515326730602111
#
#         scrape_id last_scraped       source  \
# 0  20250624193519   2025-06-26  city scrape
# 1  20250624193519   2025-06-27  city scrape
# 2  20250624193519   2025-06-27  city scrape
# 3  20250624193519   2025-06-28  city scrape
# 4  20250624193519   2025-06-26  city scrape
#
#                                             name  \
# 0              Exceptional 2 Bed Copa 100m Beach
# 1                   Tiny House Praia de Botafogo
# 2                             apartamento D Cs K
# 3  Renovated and charming close to Leblon beach!
# 4                               Ipanema_Errejota
#
#                                          description    host_id    host_name  \
# 0  2 bedroom apartment 100 meters from Copacabana...  397106841      Jump In
# 1  welcome to your Apto in Botafogo!<br /><br />G...  156783825       Morada
# 2  Relax with the whole family, or with friends  ...  674375308     Deisiana
# 3  Apartment completely renovated, modern, super ...  508835814  Rio To Stay
# 4  This cozy 1 bedroom apartment located in the h...  198908935      FlÃ¡vio
#
#    host_since  ... bedrooms beds    price review_scores_rating  \
# 0  2021-04-15  ...      2.0  4.0  $507.00                 3.00
# 1  2017-10-30  ...      1.0  1.0  $215.00                 4.82
# 2  2025-01-21  ...      2.0  4.0   $90.00                 5.00
# 3  2023-04-06  ...      2.0  3.0  $769.00                 4.75
# 4  2018-06-29  ...      1.0  2.0  $351.00                 4.82
#
#   review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                   5.00                       4.00                   2.00
# 1                   4.91                       4.91                   5.00
# 2                   5.00                       5.00                   5.00
# 3                   4.88                       4.84                   4.88
# 4                   4.82                       4.91                   4.82
#
#    review_scores_communication  review_scores_location review_scores_value
# 0                         3.00                    5.00                3.00
# 1                         4.91                    5.00                4.82
# 2                         5.00                    4.80                5.00
# 3                         4.94                    4.88                4.69
# 4                         5.00                    4.73                4.73
#
# [5 rows x 27 columns]

# %%
df.tail()
# Out:
#                         id                                       listing_url  \
# 21281  1223140834392925320  https://www.airbnb.com/rooms/1223140834392925320
# 21282  1446320012960368175  https://www.airbnb.com/rooms/1446320012960368175
# 21283  1076007360937301736  https://www.airbnb.com/rooms/1076007360937301736
# 21284  1400835747819798620  https://www.airbnb.com/rooms/1400835747819798620
# 21285             27428250             https://www.airbnb.com/rooms/27428250
#
#             scrape_id last_scraped       source  \
# 21281  20250624193519   2025-06-26  city scrape
# 21282  20250624193519   2025-06-27  city scrape
# 21283  20250624193519   2025-06-27  city scrape
# 21284  20250624193519   2025-06-26  city scrape
# 21285  20250624193519   2025-06-26  city scrape
#
#                                                    name  \
# 21281                        Quarto Corcovado MarocaRIO
# 21282                   Entre praias Ipanema Copacabana
# 21283  Copanema - Apartamento charmoso a 5 min da praia
# 21284     suite em Copacabana com cozinha e  lavanderia
# 21285           Casa inteira com piscina - Casa Insanta
#
#                                              description    host_id  \
# 21281  Welcome to the Corcovado Room, one of our fine...  139136788
# 21282  Cozy apartment between Copacabana and Ipanema,...  664003524
# 21283  Super charming and cozy apartment, just a few ...  449853878
# 21284        Take a break to relax in this serene oasis.  106226420
# 21285  This listing refers to the rental of the entir...  193205371
#
#            host_name  host_since  ... bedrooms  beds      price  \
# 21281         Marcio  2017-07-07  ...      1.0   1.0    $331.00
# 21282    JoÃ£o Pedro  2024-11-25  ...      1.0   2.0    $350.00
# 21283          Bruno  2022-03-16  ...      1.0   2.0    $489.00
# 21284  Jose ClÃ¡udio  2016-12-05  ...      1.0   2.0    $140.00
# 21285         Victor  2018-06-03  ...      6.0  16.0  $2,697.00
#
#       review_scores_rating review_scores_accuracy  review_scores_cleanliness  \
# 21281                  NaN                    NaN                        NaN
# 21282                  NaN                    NaN                        NaN
# 21283                 5.00                   5.00                       5.00
# 21284                  NaN                    NaN                        NaN
# 21285                 4.85                   4.77                       4.46
#
#        review_scores_checkin  review_scores_communication  \
# 21281                    NaN                          NaN
# 21282                    NaN                          NaN
# 21283                   5.00                          5.0
# 21284                    NaN                          NaN
# 21285                   4.92                          5.0
#
#        review_scores_location review_scores_value
# 21281                     NaN                 NaN
# 21282                     NaN                 NaN
# 21283                    5.00                4.67
# 21284                     NaN                 NaN
# 21285                    4.92                4.77
#
# [5 rows x 27 columns]

# %% [markdown]
# # Início da limpeza dos dados
#
#   - Começo selecionando apenas as colunas de interesse
#   - Após isso resolver os valores e tipagem na coluna 'price'
#   - E então verificar dados nulos e limpá-los

# %% [markdown]
#   - Há 4 tipos de imóveis: ['Entire home/apt', 'Private room', 'Shared room', 'Hotel room']
#
#   - E em price, vejo 3 problemas: cifrão, casas decimais separadas por vírgula e a tipagem como objeto(texto) '$2,697.00', dtype=object
#
#   - Já em banheiros e quartos, os dados estão tipados em float. E por curiosidade lavabos sao considerados como 0.5 no número de banheiros. Também há valores nulos em muitas variáveis.

# %%
#Listo as colunas para facilitar a copiar as colunas que quero
lista_de_colunas = df.columns
print(lista_de_colunas)
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'host_id', 'host_name', 'host_since', 'neighbourhood',
#        'neighbourhood_cleansed', 'latitude', 'longitude', 'room_type',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'price',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value'],
#       dtype='object')

# %%
dados_limpos = df.loc [:,  ['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
                            'host_since', 'latitude', 'longitude', 'room_type', 'accommodates', 'bathrooms',
                            'bedrooms', 'beds', 'price', 'review_scores_rating', 'review_scores_accuracy']]
dados_limpos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21286 entries, 0 to 21285
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      21286 non-null  int64
#  1   listing_url             21286 non-null  object
#  2   scrape_id               21286 non-null  int64
#  3   last_scraped            21286 non-null  object
#  4   name                    21286 non-null  object
#  5   description             20766 non-null  object
#  6   host_since              20495 non-null  object
#  7   latitude                21286 non-null  object
#  8   longitude               21286 non-null  object
#  9   room_type               21286 non-null  object
#  10  accommodates            21286 non-null  int64
#  11  bathrooms               19465 non-null  float64
#  12  bedrooms                20919 non-null  float64
#  13  beds                    19480 non-null  float64
#  14  price                   19486 non-null  object
#  15  review_scores_rating    16919 non-null  float64
#  16  review_scores_accuracy  16914 non-null  float64
# dtypes: float64(5), int64(3), object(9)
# memory usage: 2.8+ MB

# %%
#Loop para a quantidade e tipos de dados da base
for coluna in dados_limpos.columns:
  print("==> ", coluna, " QTD únicos: ", dados_limpos[coluna].unique())
  print(dados_limpos[coluna].unique())
  print()
# Out:
# ==>  id  QTD únicos:  [ 752318531145700331 1411843238290322081 1339188406746847719 ...
#  1076007360937301736 1400835747819798620            27428250]
# [ 752318531145700331 1411843238290322081 1339188406746847719 ...
#  1076007360937301736 1400835747819798620            27428250]
#
# ==>  listing_url  QTD únicos:  ['https://www.airbnb.com/rooms/752318531145700331'
#  'https://www.airbnb.com/rooms/1411843238290322081'
#  'https://www.airbnb.com/rooms/1339188406746847719' ...
#  'https://www.airbnb.com/rooms/1076007360937301736'
#  'https://www.airbnb.com/rooms/1400835747819798620'
#  'https://www.airbnb.com/rooms/27428250']
# ['https://www.airbnb.com/rooms/752318531145700331'
#  'https://www.airbnb.com/rooms/1411843238290322081'
#  'https://www.airbnb.com/rooms/1339188406746847719' ...
#  'https://www.airbnb.com/rooms/1076007360937301736'
#  'https://www.airbnb.com/rooms/1400835747819798620'
# ['2 bedroom apartment 100 meters from Copacabana beach (Posto 4), located on Rua Fernando Mendes, 150 meters away, surrounded by high-end hotels, which guarantees this part of the beach extra security maintained by hotels.<br /><br />The space is suitable for up to 4 people, accommodated in two rooms overlooking the street. Living room with TV, 01 bathroom, full kitchen, ceiling fan in the living room and bedrooms, air conditioning.'
#  'welcome to your Apto in Botafogo!<br /><br />Great location, close to Botafogo beach mall, volunteers from the homeland, 10 minutes from the SDU and 6 minutes from the subway!<br /><br />totalmete renovated apartment with attention to your comfort!<br /><br />-ar condicion split<br /><br />-Genicleshaft<br /><br />-televisÃ£o<br /><br />-cafeteira, sandwich maker, microwave, stove and fridge!<br /><br />welcome and make your reservation =]<br /><br />NOTE: to get to the apartment, there is a flight of stairs'
#  'Relax with the whole family, or with friends  in this quiet accommodation. We also recommend to workers. Work trip.'
#  ...
#  'Cozy apartment between Copacabana and Ipanema, a few steps from the beaches of Arpoador and Ipanema. 1 bedroom with double bed and air conditioning, living room with sofa bed and charming area with hammock.<br /><br />Quiet, well located, close to the subway, market and shops. Perfect for enjoying the best of Rio!<br /><br />Privileged ð\x9f\x8c\x8a location between Copacabana and Ipanema <br /><br />Exclusive ð\x9f\x8c¿ area with hammock<br /><br />ð\x9f\x9a\x87 Close to the subway, supermarkets and shops<br /><br />ð\x9f§º Bed linen'
#  'Super charming and cozy apartment, just a few steps away from the iconic beaches of Copacabana and Ipanema. Intimate decoration for good moments of relaxation and with all the amenities of a good refuge from the frisson of the big city. It is surrounded by shops, markets, pharmacies, bars and the best restaurants.  Building with 24h concierge and elevators. In addition to the proximity of the best beaches, it is glued to the subway, allowing you to explore all the best sights of Rio de Janeiro.'
#  'This listing refers to the rental of the entire house, with 6 bedrooms for overnight stays. Check-in and check-out times are usually 10am, being flexible according to other reservations.<br /><br />Attention to the following information, as they contain the answers to the most common questions.']
#
# ==>  host_since  QTD únicos:  ['2021-04-15' '2017-10-30' '2025-01-21' ... '2012-02-12' '2012-12-15'
#  '2013-09-13']
# ['2021-04-15' '2017-10-30' '2025-01-21' ... '2012-02-12' '2012-12-15'
#  '2013-09-13']
#
# ==>  latitude  QTD únicos:  ['-22,96635' '-22,94533' '-22,9372198' ... '-22,983059727005863'
#  '-22,9829828' '-22,91962']
# ['-22,96635' '-22,94533' '-22,9372198' ... '-22,983059727005863'
#  '-22,9829828' '-22,91962']
#
# ==>  longitude  QTD únicos:  ['-43,17938' '-43,18163' '-43,6966461' ... '-43,17201'
#  '-43,19452769999999' '-43,19366']
# ['-43,17938' '-43,18163' '-43,6966461' ... '-43,17201'
#  '-43,19452769999999' '-43,19366']
#
# ==>  room_type  QTD únicos:  ['Entire home/apt' 'Private room' 'Shared room' 'Hotel room']
# ['Entire home/apt' 'Private room' 'Shared room' 'Hotel room']
#
# ==>  accommodates  QTD únicos:  [ 5  2  4  3  1  6  8 15 14 12 10 13  7  9 16 11]
#  2.75 2.33 3.78 4.16 4.37 4.09 3.93 4.34 4.06 1.67 3.54 4.21 4.05 4.12
#  4.08 3.97 3.77]

# %%
#Primeiro limpamos a variável price
dados_limpos['price'] = dados_limpos['price'].str.replace('$', '')
dados_limpos['price'] = dados_limpos['price'].str.replace(',', '')
dados_limpos['price'].unique()
# Out:
# array(['507.00', '215.00', '90.00', ..., '849.00', '9947.00', '2697.00'],
#       dtype=object)

# %%
#Agora converto para a tipagem correta
dados_limpos['price'] = dados_limpos['price'].astype(float)
dados_limpos['price'].unique()
# Out:
# array([ 507.,  215.,   90., ...,  849., 9947., 2697.])

# %%
dados_limpos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21286 entries, 0 to 21285
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      21286 non-null  int64
#  1   listing_url             21286 non-null  object
#  2   scrape_id               21286 non-null  int64
#  3   last_scraped            21286 non-null  object
#  4   name                    21286 non-null  object
#  5   description             20766 non-null  object
#  6   host_since              20495 non-null  object
#  7   latitude                21286 non-null  object
#  8   longitude               21286 non-null  object
#  9   room_type               21286 non-null  object
#  10  accommodates            21286 non-null  int64
#  11  bathrooms               19465 non-null  float64
#  12  bedrooms                20919 non-null  float64
#  13  beds                    19480 non-null  float64
#  14  price                   19486 non-null  float64
#  15  review_scores_rating    16919 non-null  float64
#  16  review_scores_accuracy  16914 non-null  float64
# dtypes: float64(6), int64(3), object(8)
# memory usage: 2.8+ MB

# %%
(dados_limpos.isnull().sum() / len(dados_limpos)) * 100
# Out:
# id                         0.000000
# listing_url                0.000000
# scrape_id                  0.000000
# last_scraped               0.000000
# name                       0.000000
# description                2.442920
# host_since                 3.716058
# latitude                   0.000000
# longitude                  0.000000
# room_type                  0.000000
# accommodates               0.000000
# bathrooms                  8.554919
# bedrooms                   1.724138
# beds                       8.484450
# price                      8.456262
# review_scores_rating      20.515832
# review_scores_accuracy    20.539322
# dtype: float64

# %% [markdown]
# Quando os dados nulos forem menores que 10% da base podem ser apagados, mas para apagar deve haver um motivo. Para análise descritiva e estatística básica não há necessidade de apagar, mas para ML e clusterização geralmente as bibliotecas já vem prontas para lidar com os nulos apagando/ignorando ou será preciso apagá-los manualmente.<br></br>
# - A limpeza dos nulos será feita apenas em **price, bathrooms, bedrooms e beds**. Já que: reviews, host_since e description não serão relevantes ter nulos ou não.

# %%
dados_limpos = dados_limpos.dropna(subset=['price', 'bathrooms', 'bedrooms', 'beds'])
dados_limpos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19427 entries, 0 to 21285
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      19427 non-null  int64
#  1   listing_url             19427 non-null  object
#  2   scrape_id               19427 non-null  int64
#  3   last_scraped            19427 non-null  object
#  4   name                    19427 non-null  object
#  5   description             18971 non-null  object
#  6   host_since              18700 non-null  object
#  7   latitude                19427 non-null  object
#  8   longitude               19427 non-null  object
#  9   room_type               19427 non-null  object
#  10  accommodates            19427 non-null  int64
#  11  bathrooms               19427 non-null  float64
#  12  bedrooms                19427 non-null  float64
#  13  beds                    19427 non-null  float64
#  14  price                   19427 non-null  float64
#  15  review_scores_rating    15569 non-null  float64
#  16  review_scores_accuracy  15564 non-null  float64
# dtypes: float64(6), int64(3), object(8)
# memory usage: 2.7+ MB

# %%
dados_limpos[['latitude', 'longitude']]
# Out:
#                   latitude           longitude
# 0                -22,96635           -43,17938
# 1                -22,94533           -43,18163
# 2              -22,9372198         -43,6966461
# 3      -22,981651797126293  -43,22314382772875
# 4               -22,983108         -43,2026608
# ...                    ...                 ...
# 21281             -22,9693           -43,19026
# 21282          -22,9829828  -43,19452769999999
# 21283            -22,98175           -43,19286
# 21284             -22,9759           -43,19366
# 21285            -22,91962           -43,18582
#
# [19427 rows x 2 columns]

# %% [markdown]
# Os dados das colunas latitude e longitude estão salvos como texto (object) e possuem vírgula como separador, então farei basicamente o mesmo procedimento que fiz em price. Tirando a vírgula e passando o formato em float para serem acessados pelo cluster posteriormente.

# %%
dados_limpos['latitude'] = dados_limpos['latitude'].astype(str).str.replace(',', '.')
dados_limpos['longitude'] = dados_limpos['longitude'].astype(str).str.replace(',', '.')

dados_limpos['latitude'] = dados_limpos['latitude'].astype(float)
dados_limpos['longitude'] = dados_limpos['longitude'].astype(float)

# %%
dados_limpos[['latitude', 'longitude']]
# Out:
#         latitude  longitude
# 0     -22.966350 -43.179380
# 1     -22.945330 -43.181630
# 2     -22.937220 -43.696646
# 3     -22.981652 -43.223144
# 4     -22.983108 -43.202661
# ...          ...        ...
# 21281 -22.969300 -43.190260
# 21282 -22.982983 -43.194528
# 21283 -22.981750 -43.192860
# 21284 -22.975900 -43.193660
# 21285 -22.919620 -43.185820
#
# [19427 rows x 2 columns]

# %% [markdown]
# Primeiros Insights:
#   - Importante observar que review_scores_rating e review_scores_accuracy são respectivamente a avaliação e a precisão do que foi dito no anúncio do imóvel, ou seja, se possuía o que o anúncio afirmava entregar.

# %%
dados_limpos['rating_vs_accuracy'] = dados_limpos['review_scores_rating'] == dados_limpos['review_scores_accuracy']
print(dados_limpos)
# Out:
#                         id                                       listing_url  \
# 0       752318531145700331   https://www.airbnb.com/rooms/752318531145700331
# 1      1411843238290322081  https://www.airbnb.com/rooms/1411843238290322081
# 2      1339188406746847719  https://www.airbnb.com/rooms/1339188406746847719
# 3      1050604592912820183  https://www.airbnb.com/rooms/1050604592912820183
# 4      1349515326730602111  https://www.airbnb.com/rooms/1349515326730602111
# ...                    ...                                               ...
# 21281  1223140834392925320  https://www.airbnb.com/rooms/1223140834392925320
# 21282  1446320012960368175  https://www.airbnb.com/rooms/1446320012960368175
# 21283  1076007360937301736  https://www.airbnb.com/rooms/1076007360937301736
# 21284  1400835747819798620  https://www.airbnb.com/rooms/1400835747819798620
# 21285             27428250             https://www.airbnb.com/rooms/27428250
#
#             scrape_id last_scraped  \
# 0      20250624193519   2025-06-26
# 1      20250624193519   2025-06-27
# 2      20250624193519   2025-06-27
# 3      20250624193519   2025-06-28
# 4      20250624193519   2025-06-26
# ...               ...          ...
# 21281  20250624193519   2025-06-26
# 21282  20250624193519   2025-06-27
# 21283  20250624193519   2025-06-27
# 21284  20250624193519   2025-06-26
# 21285  20250624193519   2025-06-26
#
#                                                    name  \
# 0                     Exceptional 2 Bed Copa 100m Beach
# 1                          Tiny House Praia de Botafogo
# 2                                    apartamento D Cs K
# 3         Renovated and charming close to Leblon beach!
# 4                                      Ipanema_Errejota
# ...                                                 ...
# 21281                        Quarto Corcovado MarocaRIO
# 21282                   Entre praias Ipanema Copacabana
# 21283  Copanema - Apartamento charmoso a 5 min da praia
# 21284     suite em Copacabana com cozinha e  lavanderia
# 21285           Casa inteira com piscina - Casa Insanta
#
#                                              description  host_since  \
# 0      2 bedroom apartment 100 meters from Copacabana...  2021-04-15
# 1      welcome to your Apto in Botafogo!<br /><br />G...  2017-10-30
# 2      Relax with the whole family, or with friends  ...  2025-01-21
# 3      Apartment completely renovated, modern, super ...  2023-04-06
# 4      This cozy 1 bedroom apartment located in the h...  2018-06-29
# ...                                                  ...         ...
# 21281  Welcome to the Corcovado Room, one of our fine...  2017-07-07
# 21282  Cozy apartment between Copacabana and Ipanema,...  2024-11-25
# 21283  Super charming and cozy apartment, just a few ...  2022-03-16
# 21284        Take a break to relax in this serene oasis.  2016-12-05
# 21285  This listing refers to the rental of the entir...  2018-06-03
#
#         latitude  longitude        room_type  accommodates  bathrooms  \
# 0     -22.966350 -43.179380  Entire home/apt             5        1.0
# 1     -22.945330 -43.181630  Entire home/apt             2        1.0
# 2     -22.937220 -43.696646  Entire home/apt             4        1.0
# 3     -22.981652 -43.223144  Entire home/apt             5        2.0
# 4     -22.983108 -43.202661  Entire home/apt             4        1.5
# ...          ...        ...              ...           ...        ...
# 21281 -22.969300 -43.190260     Private room             2        1.0
# 21282 -22.982983 -43.194528  Entire home/apt             3        1.0
# 21283 -22.981750 -43.192860  Entire home/apt             3        2.0
# 21284 -22.975900 -43.193660     Private room             2        1.0
# 21285 -22.919620 -43.185820  Entire home/apt            16        5.5
#
#        bedrooms  beds   price  review_scores_rating  review_scores_accuracy  \
# 0           2.0   4.0   507.0                  3.00                    5.00
# 1           1.0   1.0   215.0                  4.82                    4.91
# 2           2.0   4.0    90.0                  5.00                    5.00
# 3           2.0   3.0   769.0                  4.75                    4.88
# 4           1.0   2.0   351.0                  4.82                    4.82
# ...         ...   ...     ...                   ...                     ...
# 21281       1.0   1.0   331.0                   NaN                     NaN
# 21282       1.0   2.0   350.0                   NaN                     NaN
# 21283       1.0   2.0   489.0                  5.00                    5.00
# 21284       1.0   2.0   140.0                   NaN                     NaN
# 21285       6.0  16.0  2697.0                  4.85                    4.77
#
#        rating_vs_accuracy
# 0                   False
# 1                   False
# 2                    True
# 3                   False
# 4                    True
# ...                   ...
# 21281               False
# 21282               False
# 21283                True
# 21284               False
# 21285               False
#
# [19427 rows x 18 columns]

# %%
#Salvar csv para posteridade
dados_limpos.to_csv("dados_limpos.csv", index=False)
